# %% [markdown]
# # 1 Time Series Forecasting with XGBoost

# %% [markdown]
# ## 1.1 Contents<a id='1.1_Contents'></a>
# * [1 Time Series Forecasting with XGBoost](#1_Time_Series_Forecasting_with_XGBoost)
#   * [1.1 Contents](#1.1_Contents)
#   * [1.2 Overview](#1.2_Overview)
#   * [1.3 Imports](#1.3_Imports)
#   * [1.4 Functions](#1.4_Functions)
#      * [1.4.1 Functions: series_to_supervised](#1.4.1_Functions:_series_to_superviesed)
#      * [1.4.2 Functions: walk_forward_validation](#1.4.2_Functions:_walk_forward_validation)
#      * [1.4.3 Functions: random_forest_forecast](#1.4.3_Functions:_random_forest_forecast)
#      * [1.4.4 Functions: train_test_split](#1.4.4_Functions:_train_test_split)
#      * [1.4.5 Functions: create_lagged_df](#1.4.5_Functions:_create_lagged_df)
#   * [1.5 Load Data](#1.5_Load_Data)
#   * [1.6 Organize Features and Targets with Lagging](#1.6_Organize_Features_and_Targets_with_Lagging)
#   * [1.7 Fit and Evaluate the Model](#1.7_Fit_and_Evaluate_the_Model)
#   * [1.8 Visualize Model Performance](#1.8_Visualize_Model_Performance)
#      * [1.8.1 Plot Actual and Predicted Cases](#1.8.1_Plot_Actual_and_Predicted_Cases)
#      * [1.8.2 Bar Plot the Mean Absolute Errors](#1.8.2_Bar_Plot_MAE)
#      * [1.8.3 Horizontal Bar Plot for Feature Importances](#1.8.3_Horizontal_Bar_Plot_Feature_Importances)
#   * [1.9 Save the Model](#1.9_Save_the_Model)

# %% [markdown]
# ## 1.2 Overview<a id='1.2_Overview'></a>

# %% [markdown]
# Add overview here!

# %% [markdown]
# ## 1.3 Imports<a id='1.3_Imports'></a>

# %%
from collections import defaultdict
from pathlib import Path
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
import graphviz
from pathlib import Path
from xgboost import XGBRegressor
from deepdiff import DeepDiff
from sklearn.metrics import mean_absolute_error
from sklearn.tree import export_graphviz
# %matplotlib inline

# Set Matplotlib defaults
plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True, figsize=(11, 5))
plt.rc(
    "axes",
    labelweight="bold",
    labelsize=14,
    titleweight="bold",
    titlesize=16,
    titlepad=10,
)
plot_params = dict(
    color="0.75",
    style=".-",
    markeredgecolor="0.25",
    markerfacecolor="0.25",
)

# %% [markdown]
# ## 1.4 Functions<a id='1.4_Functions'></a>

# %% [markdown]
# ### 1.4.1 Functions: series_to_supervised<a id='1.4.1_Functions:_series_to_superviesed'></a>

# %%
# transform a time series dataset into a supervised learning dataset
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	#n_vars = 1 if type(data) is list else data.shape[1]
	df1 = pd.DataFrame(data)
	cols = list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df1.shift(i))
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df1.shift(-i))
	# put it all together
	agg = pd.concat(cols, axis=1)
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg.values

# %% [markdown]
# ### 1.4.2 Functions: walk_forward_validation<a id='1.4.2_Functions:_walk_forward_validation'></a>

# %%
def walk_forward_validation(data, n_test, n_out=1):
    predictions = list()
	# split dataset
    train, test = train_test_split(data, n_test) # np arrays
	# seed history with training dataset
    history = [x for x in train] # array to list (why list? Easier to append?)
	# step over each time-step in the test set
    for i in range(len(test)):
		# split test row into input and output columns
        testX, testy = test[i, :-n_out], test[i, -n_out:]
		# fit model on history and make a prediction
        yhat, modelXG = xgboost_forecast(history, testX, n_out)
		# store forecast in list of predictions
        predictions.append(yhat)
		# add actual observation to history for the next loop
        history.append(test[i])
		# summarize progress
        print('>expected=%.1f, predicted=%.1f' % (np.mean(testy), np.mean(yhat)))	
    # estimate prediction error
    error = mean_absolute_error(test[:, -n_out:], predictions)
    return error, test[:, -n_out:], predictions, modelXG

# %% [markdown]
# ### 1.4.3 Functions: XGBoost<a id='1.4.3_Functions:_XGBoost'></a>

# %%
# fit an xgboost model and make a one step prediction
def xgboost_forecast(train, testX, n_out=1):
	# transform list into array
	train = np.asarray(train)
	# split into input and output columns
	trainX, trainy = train[:, :-n_out], train[:, -n_out:]
	# fit model
	model = XGBRegressor(objective='reg:squarederror', n_estimators=1000)
	model.fit(trainX, trainy)
	# make a one-step prediction
	yhat = model.predict(np.asarray([testX]))
	return yhat[0], model

# %% [markdown]
# ### 1.4.4 Functions: train_test_split<a id='1.4.4_Functions:_train_test_split'></a>

# %%
def train_test_split(data, n_test):
    return data[:-n_test,:], data[-n_test:,:]

# %% [markdown]
# ### 1.4.5 Functions: create_lagged_df<a id='1.4.5_Functions:_create_lagged_df'></a>

# %%
def create_lagged_df(dataframeToLag, n_in=1, n_out=1, dropnan=False):
    dataframeToLag = pd.DataFrame(dataframeToLag)
    df_lagged = pd.DataFrame()
    df_lagged['date'] = dataframeToLag.index
    for col in dataframeToLag.columns:
        lag_arr = series_to_supervised(dataframeToLag[col], n_in, n_out, dropnan=False)
        lag_columns = [(col+'_'+str(lag)) for lag in range(n_in,-n_out,-1)]
        for lag in range(0,n_in+n_out):
            df_lagged[lag_columns[lag]]=lag_arr[:,lag]
    df_lagged.set_index('date', inplace=True)
    return df_lagged

# %% [markdown]
# ## 1.5 Load Data<a id='1.5_Load_Data'></a>

# %%
# load the saved dictionary from pickle file
filePath_pickle = Path('/Users/parkj/Documents/pyDat/dataSet/covid_countryData.pickle')
pickle_in = open(filePath_pickle, 'rb')
country_dict = pickle.load(pickle_in)
df = country_dict['United States']

# %% [markdown]
# ## 1.6 Organize Features and Targets with Lagging<a id='1.6_Organize_Features_and_Targets_with_Lagging'></a>

# %%
# time series (non-case) features 
features_lag = ['rtrc', 'grph', 'prks', 'tran', 'work', 'resi', 'vac', 'dayow']
# evaluate
n_test = 100
# non-case features (mobility, vaccination, dayow) with lagging for previous 7 days
df_feat_non_case_lag = create_lagged_df(df.loc[:,features_lag], n_in=7, n_out=0, dropnan=False)
# lagged case features for previous 7 days
df_feat_case_lag = create_lagged_df(df.case_mil_percMax, n_in=7, n_out=0, dropnan=False)
# join features 
df_feat_lag = df_feat_non_case_lag.join(df_feat_case_lag, on='date', how='left')
# target variables for next 7 days
df_targ_7day = create_lagged_df(df.case_mil_percMax, n_in=0, n_out=7, dropnan=False)

# %% [markdown]
# ## 1.7 Fit and Evaluate the Model for 7-day forecast<a id='1.7_Fit_and_Evaluate_the_Model'></a>

# %%
# build models to predict each of the next 7 days
rez_XGBoost_dict = {}
for i in range(7):
    df_targ_this = df_targ_7day.drop(df_targ_7day.columns[[j for j in range(n_out) if j not in [i]]], axis=1, inplace=False)
    # join the feature and target data frames 
    df_feat_targ = df_feat_lag.join(df_targ_this, on='date', how='left')
    # drop NaNs
    df_feat_targ.dropna(inplace=True)
    # fit XGBoost model with walk-forward-validation
    error, y, yhat, modelXG = walk_forward_validation(df_feat_targ.values, n_test, n_out=1) # n_test = 100
    # dataframe y and yhat
    df_y_yhat = pd.DataFrame({'date':df_feat_targ.index[-n_test:], 'y': [float(i) for i in y], 'yhat': yhat})
    # bundle up the results
    rez_XGBoost_dict[df_targ_this.columns[0]] = {'error':error, 'y_yhat':df_y_yhat, 'model':modelXG}
# Out:
# /Users/parkj/opt/anaconda3/envs/pydeep/lib/python3.8/site-packages/xgboost/data.py:104: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# >expected=22.1, predicted=23.0
# >expected=19.4, predicted=20.7
# >expected=13.7, predicted=17.5
# >expected=14.9, predicted=16.7
# >expected=19.2, predicted=16.3
# >expected=19.3, predicted=19.4
# >expected=20.8, predicted=19.7
# >expected=20.5, predicted=21.7
# >expected=17.6, predicted=18.2
# >expected=12.7, predicted=15.3
# >expected=18.8, predicted=17.3
# >expected=18.0, predicted=16.9
# >expected=19.7, predicted=18.7
# >expected=20.1, predicted=20.3
# >expected=20.5, predicted=21.0
# >expected=18.5, predicted=17.1
# >expected=11.3, predicted=14.5
# >expected=17.1, predicted=11.8
# >expected=17.9, predicted=15.3
# >expected=28.9, predicted=18.2
# >expected=22.5, predicted=26.0
# >expected=25.8, predicted=21.8
# >expected=20.9, predicted=21.4
# >expected=14.4, predicted=14.3
# >expected=23.1, predicted=19.1
# >expected=20.4, predicted=20.2
# >expected=22.2, predicted=25.7
# >expected=26.3, predicted=22.9
# >expected=23.3, predicted=26.4
# >expected=21.1, predicted=21.6
# >expected=11.7, predicted=18.9
# >expected=25.8, predicted=19.8
# >expected=20.2, predicted=23.9
# >expected=25.0, predicted=24.5
# >expected=26.6, predicted=23.0
# >expected=27.5, predicted=24.1
# >expected=22.2, predicted=25.4
# >expected=15.5, predicted=15.9
# >expected=23.3, predicted=24.8
# >expected=25.9, predicted=22.4
# >expected=25.1, predicted=26.5
# >expected=24.7, predicted=25.9
# >expected=26.6, predicted=24.8
# >expected=17.5, predicted=24.1
# >expected=14.0, predicted=17.7
# >expected=22.7, predicted=21.8
# >expected=20.3, predicted=22.1
# >expected=20.9, predicted=22.9
# >expected=22.4, predicted=25.3
# >expected=20.8, predicted=22.6
# >expected=17.8, predicted=17.7
# >expected=10.7, predicted=16.1
# >expected=15.8, predicted=17.9
# >expected=16.9, predicted=19.4
# >expected=18.4, predicted=19.4
# >expected=19.4, predicted=20.1
# >expected=19.3, predicted=21.3
# >expected=15.1, predicted=18.1
# >expected=9.8, predicted=11.8
# >expected=16.8, predicted=12.6
# >expected=13.6, predicted=14.4
# >expected=14.9, predicted=15.5
# >expected=15.8, predicted=17.6
# >expected=16.0, predicted=14.3
# >expected=11.2, predicted=14.4
# >expected=7.1, predicted=9.7
# >expected=12.2, predicted=13.8
# >expected=11.2, predicted=12.8
# >expected=11.9, predicted=11.2
# >expected=12.7, predicted=11.8
# >expected=14.1, predicted=14.6
# >expected=9.6, predicted=10.7
# >expected=5.6, predicted=7.1
# >expected=9.5, predicted=7.2
# >expected=9.2, predicted=8.2
# >expected=9.7, predicted=8.5
# >expected=10.1, predicted=10.7
# >expected=9.3, predicted=10.0
# >expected=6.6, predicted=5.6
# >expected=4.3, predicted=7.4
# >expected=8.6, predicted=5.9
# >expected=7.6, predicted=9.1
# >expected=8.0, predicted=6.9
# >expected=9.1, predicted=8.0
# >expected=7.3, predicted=8.2
# >expected=4.0, predicted=7.9
# >expected=2.2, predicted=4.4
# >expected=1.9, predicted=2.4
# >expected=7.6, predicted=2.1
# >expected=5.6, predicted=7.0
# >expected=6.3, predicted=5.3
# >expected=5.6, predicted=5.2
# >expected=4.6, predicted=4.6
# >expected=1.8, predicted=2.6
# >expected=5.2, predicted=6.2
# >expected=4.3, predicted=6.8
# >expected=6.2, predicted=5.2
# >expected=4.8, predicted=5.5
# >expected=8.2, predicted=5.2
# >expected=2.7, predicted=3.8
# /Users/parkj/opt/anaconda3/envs/pydeep/lib/python3.8/site-packages/xgboost/data.py:104: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# >expected=22.1, predicted=21.9
# >expected=19.4, predicted=22.9
# >expected=13.7, predicted=19.6
# >expected=14.9, predicted=18.0
# >expected=19.2, predicted=15.4
# >expected=19.3, predicted=19.3
# >expected=20.8, predicted=19.7
# >expected=20.5, predicted=20.3
# >expected=17.6, predicted=16.8
# >expected=12.7, predicted=13.4
# >expected=18.8, predicted=16.2
# >expected=18.0, predicted=17.6
# >expected=19.7, predicted=19.0
# >expected=20.1, predicted=20.3
# >expected=20.5, predicted=20.6
# >expected=18.5, predicted=15.3
# >expected=11.3, predicted=13.8
# >expected=17.1, predicted=16.3
# >expected=17.9, predicted=16.2
# >expected=28.9, predicted=18.5
# >expected=22.5, predicted=23.8
# >expected=25.8, predicted=27.4
# >expected=20.9, predicted=17.2
# >expected=14.4, predicted=13.3
# >expected=23.1, predicted=18.0
# >expected=20.4, predicted=20.8
# >expected=22.2, predicted=26.6
# >expected=26.3, predicted=24.3
# >expected=23.3, predicted=23.2
# >expected=21.1, predicted=22.4
# >expected=11.7, predicted=18.7
# >expected=25.8, predicted=20.1
# >expected=20.2, predicted=20.8
# >expected=25.0, predicted=25.3
# >expected=26.6, predicted=24.6
# >expected=27.5, predicted=25.0
# >expected=22.2, predicted=25.2
# >expected=15.5, predicted=14.5
# >expected=23.3, predicted=22.6
# >expected=25.9, predicted=21.3
# >expected=25.1, predicted=25.7
# >expected=24.7, predicted=26.1
# >expected=26.6, predicted=23.8
# >expected=17.5, predicted=21.1
# >expected=14.0, predicted=17.1
# >expected=22.7, predicted=23.9
# >expected=20.3, predicted=23.1
# >expected=20.9, predicted=25.5
# >expected=22.4, predicted=22.5
# >expected=20.8, predicted=23.8
# >expected=17.8, predicted=18.3
# >expected=10.7, predicted=15.3
# >expected=15.8, predicted=20.5
# >expected=16.9, predicted=18.8
# >expected=18.4, predicted=18.0
# >expected=19.4, predicted=17.4
# >expected=19.3, predicted=19.2
# >expected=15.1, predicted=17.8
# >expected=9.8, predicted=12.9
# >expected=16.8, predicted=12.7
# >expected=13.6, predicted=13.9
# >expected=14.9, predicted=17.8
# >expected=15.8, predicted=16.5
# >expected=16.0, predicted=17.4
# >expected=11.2, predicted=15.7
# >expected=7.1, predicted=12.9
# >expected=12.2, predicted=12.9
# >expected=11.2, predicted=8.1
# >expected=11.9, predicted=11.6
# >expected=12.7, predicted=12.4
# >expected=14.1, predicted=13.5
# >expected=9.6, predicted=8.6
# >expected=5.6, predicted=9.9
# >expected=9.5, predicted=6.9
# >expected=9.2, predicted=6.5
# >expected=9.7, predicted=11.0
# >expected=10.1, predicted=10.7
# >expected=9.3, predicted=9.5
# >expected=6.6, predicted=7.5
# >expected=4.3, predicted=6.7
# >expected=8.6, predicted=6.6
# >expected=7.6, predicted=8.2
# >expected=8.0, predicted=8.5
# >expected=9.1, predicted=9.0
# >expected=7.3, predicted=8.7
# >expected=4.0, predicted=7.1
# >expected=2.2, predicted=4.1
# >expected=1.9, predicted=7.2
# >expected=7.6, predicted=3.1
# >expected=5.6, predicted=7.6
# >expected=6.3, predicted=6.5
# >expected=5.6, predicted=6.2
# >expected=4.6, predicted=5.1
# >expected=1.8, predicted=2.9
# >expected=5.2, predicted=4.7
# >expected=4.3, predicted=8.1
# >expected=6.2, predicted=6.0
# >expected=4.8, predicted=4.3
# >expected=8.2, predicted=5.9
# >expected=2.7, predicted=1.2
# /Users/parkj/opt/anaconda3/envs/pydeep/lib/python3.8/site-packages/xgboost/data.py:104: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# >expected=22.1, predicted=24.1
# >expected=19.4, predicted=22.7
# >expected=13.7, predicted=15.6
# >expected=14.9, predicted=16.8
# >expected=19.2, predicted=16.8
# >expected=19.3, predicted=18.3
# >expected=20.8, predicted=17.5
# >expected=20.5, predicted=22.5
# >expected=17.6, predicted=17.5
# >expected=12.7, predicted=13.6
# >expected=18.8, predicted=13.2
# >expected=18.0, predicted=17.7
# >expected=19.7, predicted=17.3
# >expected=20.1, predicted=19.5
# >expected=20.5, predicted=20.9
# >expected=18.5, predicted=15.9
# >expected=11.3, predicted=13.9
# >expected=17.1, predicted=16.9
# >expected=17.9, predicted=15.7
# >expected=28.9, predicted=18.4
# >expected=22.5, predicted=22.4
# >expected=25.8, predicted=21.0
# >expected=20.9, predicted=18.9
# >expected=14.4, predicted=8.4
# >expected=23.1, predicted=14.5
# >expected=20.4, predicted=21.3
# >expected=22.2, predicted=27.8
# >expected=26.3, predicted=24.3
# >expected=23.3, predicted=22.3
# >expected=21.1, predicted=19.1
# >expected=11.7, predicted=18.4
# >expected=25.8, predicted=21.0
# >expected=20.2, predicted=23.6
# >expected=25.0, predicted=25.0
# >expected=26.6, predicted=19.6
# >expected=27.5, predicted=22.4
# >expected=22.2, predicted=21.8
# >expected=15.5, predicted=10.2
# >expected=23.3, predicted=26.0
# >expected=25.9, predicted=23.5
# >expected=25.1, predicted=24.8
# >expected=24.7, predicted=25.4
# >expected=26.6, predicted=24.8
# >expected=17.5, predicted=22.8
# >expected=14.0, predicted=17.6
# >expected=22.7, predicted=27.4
# >expected=20.3, predicted=24.1
# >expected=20.9, predicted=23.4
# >expected=22.4, predicted=23.4
# >expected=20.8, predicted=21.3
# >expected=17.8, predicted=18.3
# >expected=10.7, predicted=13.2
# >expected=15.8, predicted=20.9
# >expected=16.9, predicted=21.7
# >expected=18.4, predicted=19.0
# >expected=19.4, predicted=20.4
# >expected=19.3, predicted=20.0
# >expected=15.1, predicted=16.6
# >expected=9.8, predicted=12.9
# >expected=16.8, predicted=14.9
# >expected=13.6, predicted=14.7
# >expected=14.9, predicted=14.7
# >expected=15.8, predicted=17.7
# >expected=16.0, predicted=16.7
# >expected=11.2, predicted=17.5
# >expected=7.1, predicted=13.5
# >expected=12.2, predicted=12.6
# >expected=11.2, predicted=12.9
# >expected=11.9, predicted=9.5
# >expected=12.7, predicted=15.9
# >expected=14.1, predicted=14.1
# >expected=9.6, predicted=10.7
# >expected=5.6, predicted=9.4
# >expected=9.5, predicted=9.6
# >expected=9.2, predicted=9.1
# >expected=9.7, predicted=8.6
# >expected=10.1, predicted=9.1
# >expected=9.3, predicted=9.5
# >expected=6.6, predicted=6.4
# >expected=4.3, predicted=6.5
# >expected=8.6, predicted=8.0
# >expected=7.6, predicted=8.4
# >expected=8.0, predicted=8.9
# >expected=9.1, predicted=9.1
# >expected=7.3, predicted=8.1
# >expected=4.0, predicted=6.8
# >expected=2.2, predicted=4.5
# >expected=1.9, predicted=6.2
# >expected=7.6, predicted=5.2
# >expected=5.6, predicted=6.8
# >expected=6.3, predicted=2.7
# >expected=5.6, predicted=6.9
# >expected=4.6, predicted=4.8
# >expected=1.8, predicted=3.0
# >expected=5.2, predicted=4.6
# >expected=4.3, predicted=7.9
# >expected=6.2, predicted=6.8
# >expected=4.8, predicted=5.2
# >expected=8.2, predicted=5.5
# >expected=2.7, predicted=3.4
# /Users/parkj/opt/anaconda3/envs/pydeep/lib/python3.8/site-packages/xgboost/data.py:104: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# >expected=22.1, predicted=24.2
# >expected=19.4, predicted=20.4
# >expected=13.7, predicted=17.9
# >expected=14.9, predicted=19.7
# >expected=19.2, predicted=16.0
# >expected=19.3, predicted=20.0
# >expected=20.8, predicted=18.6
# >expected=20.5, predicted=20.7
# >expected=17.6, predicted=16.6
# >expected=12.7, predicted=14.7
# >expected=18.8, predicted=14.5
# >expected=18.0, predicted=19.2
# >expected=19.7, predicted=19.0
# >expected=20.1, predicted=20.9
# >expected=20.5, predicted=20.8
# >expected=18.5, predicted=15.3
# >expected=11.3, predicted=15.4
# >expected=17.1, predicted=18.1
# >expected=17.9, predicted=17.8
# >expected=28.9, predicted=17.9
# >expected=22.5, predicted=20.8
# >expected=25.8, predicted=21.6
# >expected=20.9, predicted=17.8
# >expected=14.4, predicted=7.9
# >expected=23.1, predicted=12.6
# >expected=20.4, predicted=20.6
# >expected=22.2, predicted=25.3
# >expected=26.3, predicted=24.2
# >expected=23.3, predicted=24.0
# >expected=21.1, predicted=20.4
# >expected=11.7, predicted=18.6
# >expected=25.8, predicted=21.5
# >expected=20.2, predicted=24.1
# >expected=25.0, predicted=24.0
# >expected=26.6, predicted=23.6
# >expected=27.5, predicted=23.2
# >expected=22.2, predicted=20.4
# >expected=15.5, predicted=12.1
# >expected=23.3, predicted=25.0
# >expected=25.9, predicted=19.9
# >expected=25.1, predicted=26.5
# >expected=24.7, predicted=25.3
# >expected=26.6, predicted=24.7
# >expected=17.5, predicted=22.7
# >expected=14.0, predicted=18.6
# >expected=22.7, predicted=23.9
# >expected=20.3, predicted=22.9
# >expected=20.9, predicted=25.1
# >expected=22.4, predicted=22.5
# >expected=20.8, predicted=24.2
# >expected=17.8, predicted=18.6
# >expected=10.7, predicted=14.1
# >expected=15.8, predicted=18.3
# >expected=16.9, predicted=18.4
# >expected=18.4, predicted=16.9
# >expected=19.4, predicted=18.3
# >expected=19.3, predicted=19.7
# >expected=15.1, predicted=17.2
# >expected=9.8, predicted=13.6
# >expected=16.8, predicted=17.0
# >expected=13.6, predicted=14.7
# >expected=14.9, predicted=16.5
# >expected=15.8, predicted=16.5
# >expected=16.0, predicted=18.7
# >expected=11.2, predicted=13.7
# >expected=7.1, predicted=12.4
# >expected=12.2, predicted=14.3
# >expected=11.2, predicted=13.9
# >expected=11.9, predicted=10.8
# >expected=12.7, predicted=12.3
# >expected=14.1, predicted=11.7
# >expected=9.6, predicted=9.9
# >expected=5.6, predicted=7.6
# >expected=9.5, predicted=9.7
# >expected=9.2, predicted=8.1
# >expected=9.7, predicted=10.8
# >expected=10.1, predicted=10.8
# >expected=9.3, predicted=9.8
# >expected=6.6, predicted=5.5
# >expected=4.3, predicted=7.0
# >expected=8.6, predicted=7.9
# >expected=7.6, predicted=6.6
# >expected=8.0, predicted=8.2
# >expected=9.1, predicted=9.0
# >expected=7.3, predicted=7.8
# >expected=4.0, predicted=6.4
# >expected=2.2, predicted=4.4
# >expected=1.9, predicted=7.9
# >expected=7.6, predicted=4.6
# >expected=5.6, predicted=6.8
# >expected=6.3, predicted=4.6
# >expected=5.6, predicted=6.2
# >expected=4.6, predicted=6.9
# >expected=1.8, predicted=3.3
# >expected=5.2, predicted=4.0
# >expected=4.3, predicted=6.6
# >expected=6.2, predicted=5.9
# >expected=4.8, predicted=5.1
# >expected=8.2, predicted=6.0
# >expected=2.7, predicted=3.3
# /Users/parkj/opt/anaconda3/envs/pydeep/lib/python3.8/site-packages/xgboost/data.py:104: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# >expected=22.1, predicted=23.5
# >expected=19.4, predicted=22.5
# >expected=13.7, predicted=18.3
# >expected=14.9, predicted=21.1
# >expected=19.2, predicted=17.0
# >expected=19.3, predicted=19.8
# >expected=20.8, predicted=21.4
# >expected=20.5, predicted=22.2
# >expected=17.6, predicted=17.8
# >expected=12.7, predicted=13.9
# >expected=18.8, predicted=13.9
# >expected=18.0, predicted=17.8
# >expected=19.7, predicted=18.7
# >expected=20.1, predicted=20.5
# >expected=20.5, predicted=19.6
# >expected=18.5, predicted=13.3
# >expected=11.3, predicted=16.8
# >expected=17.1, predicted=17.2
# >expected=17.9, predicted=17.6
# >expected=28.9, predicted=19.0
# >expected=22.5, predicted=18.4
# >expected=25.8, predicted=18.5
# >expected=20.9, predicted=17.9
# >expected=14.4, predicted=8.4
# >expected=23.1, predicted=13.3
# >expected=20.4, predicted=22.1
# >expected=22.2, predicted=23.2
# >expected=26.3, predicted=22.8
# >expected=23.3, predicted=25.3
# >expected=21.1, predicted=21.9
# >expected=11.7, predicted=16.8
# >expected=25.8, predicted=23.3
# >expected=20.2, predicted=25.8
# >expected=25.0, predicted=25.3
# >expected=26.6, predicted=24.6
# >expected=27.5, predicted=24.0
# >expected=22.2, predicted=22.7
# >expected=15.5, predicted=12.1
# >expected=23.3, predicted=21.7
# >expected=25.9, predicted=24.9
# >expected=25.1, predicted=22.7
# >expected=24.7, predicted=25.4
# >expected=26.6, predicted=24.5
# >expected=17.5, predicted=21.9
# >expected=14.0, predicted=17.0
# >expected=22.7, predicted=24.1
# >expected=20.3, predicted=24.4
# >expected=20.9, predicted=26.8
# >expected=22.4, predicted=23.7
# >expected=20.8, predicted=23.8
# >expected=17.8, predicted=19.0
# >expected=10.7, predicted=13.8
# >expected=15.8, predicted=19.5
# >expected=16.9, predicted=20.4
# >expected=18.4, predicted=20.3
# >expected=19.4, predicted=20.2
# >expected=19.3, predicted=19.4
# >expected=15.1, predicted=14.6
# >expected=9.8, predicted=12.8
# >expected=16.8, predicted=15.4
# >expected=13.6, predicted=15.7
# >expected=14.9, predicted=16.1
# >expected=15.8, predicted=17.9
# >expected=16.0, predicted=15.7
# >expected=11.2, predicted=14.0
# >expected=7.1, predicted=13.7
# >expected=12.2, predicted=16.8
# >expected=11.2, predicted=13.4
# >expected=11.9, predicted=13.3
# >expected=12.7, predicted=15.5
# >expected=14.1, predicted=13.5
# >expected=9.6, predicted=10.1
# >expected=5.6, predicted=7.6
# >expected=9.5, predicted=10.1
# >expected=9.2, predicted=10.4
# >expected=9.7, predicted=9.6
# >expected=10.1, predicted=9.6
# >expected=9.3, predicted=10.5
# >expected=6.6, predicted=8.3
# >expected=4.3, predicted=6.5
# >expected=8.6, predicted=6.3
# >expected=7.6, predicted=6.9
# >expected=8.0, predicted=6.2
# >expected=9.1, predicted=8.5
# >expected=7.3, predicted=6.8
# >expected=4.0, predicted=6.9
# >expected=2.2, predicted=4.2
# >expected=1.9, predicted=6.9
# >expected=7.6, predicted=5.2
# >expected=5.6, predicted=6.1
# >expected=6.3, predicted=5.8
# >expected=5.6, predicted=5.7
# >expected=4.6, predicted=6.3
# >expected=1.8, predicted=4.9
# >expected=5.2, predicted=3.9
# >expected=4.3, predicted=6.8
# >expected=6.2, predicted=7.3
# >expected=4.8, predicted=5.9
# >expected=8.2, predicted=7.4
# >expected=2.7, predicted=2.4
# /Users/parkj/opt/anaconda3/envs/pydeep/lib/python3.8/site-packages/xgboost/data.py:104: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# >expected=22.1, predicted=25.1
# >expected=19.4, predicted=24.6
# >expected=13.7, predicted=22.2
# >expected=14.9, predicted=17.6
# >expected=19.2, predicted=14.8
# >expected=19.3, predicted=21.2
# >expected=20.8, predicted=20.9
# >expected=20.5, predicted=21.9
# >expected=17.6, predicted=16.6
# >expected=12.7, predicted=11.4
# >expected=18.8, predicted=13.5
# >expected=18.0, predicted=18.5
# >expected=19.7, predicted=19.0
# >expected=20.1, predicted=21.6
# >expected=20.5, predicted=21.7
# >expected=18.5, predicted=13.7
# >expected=11.3, predicted=16.0
# >expected=17.1, predicted=19.2
# >expected=17.9, predicted=18.3
# >expected=28.9, predicted=18.9
# >expected=22.5, predicted=25.6
# >expected=25.8, predicted=23.2
# >expected=20.9, predicted=17.4
# >expected=14.4, predicted=14.3
# >expected=23.1, predicted=13.4
# >expected=20.4, predicted=25.7
# >expected=22.2, predicted=28.9
# >expected=26.3, predicted=22.9
# >expected=23.3, predicted=25.0
# >expected=21.1, predicted=20.4
# >expected=11.7, predicted=14.2
# >expected=25.8, predicted=22.6
# >expected=20.2, predicted=21.2
# >expected=25.0, predicted=24.8
# >expected=26.6, predicted=25.6
# >expected=27.5, predicted=23.5
# >expected=22.2, predicted=22.0
# >expected=15.5, predicted=13.9
# >expected=23.3, predicted=23.0
# >expected=25.9, predicted=22.5
# >expected=25.1, predicted=24.1
# >expected=24.7, predicted=28.1
# >expected=26.6, predicted=23.9
# >expected=17.5, predicted=20.2
# >expected=14.0, predicted=17.4
# >expected=22.7, predicted=25.8
# >expected=20.3, predicted=23.3
# >expected=20.9, predicted=21.8
# >expected=22.4, predicted=25.4
# >expected=20.8, predicted=21.5
# >expected=17.8, predicted=18.6
# >expected=10.7, predicted=14.7
# >expected=15.8, predicted=18.6
# >expected=16.9, predicted=19.5
# >expected=18.4, predicted=19.1
# >expected=19.4, predicted=18.3
# >expected=19.3, predicted=18.6
# >expected=15.1, predicted=17.4
# >expected=9.8, predicted=12.0
# >expected=16.8, predicted=14.3
# >expected=13.6, predicted=15.8
# >expected=14.9, predicted=15.6
# >expected=15.8, predicted=16.6
# >expected=16.0, predicted=16.4
# >expected=11.2, predicted=18.3
# >expected=7.1, predicted=11.5
# >expected=12.2, predicted=15.8
# >expected=11.2, predicted=14.2
# >expected=11.9, predicted=12.8
# >expected=12.7, predicted=15.1
# >expected=14.1, predicted=13.1
# >expected=9.6, predicted=9.7
# >expected=5.6, predicted=6.8
# >expected=9.5, predicted=9.7
# >expected=9.2, predicted=10.2
# >expected=9.7, predicted=9.3
# >expected=10.1, predicted=10.0
# >expected=9.3, predicted=12.1
# >expected=6.6, predicted=6.6
# >expected=4.3, predicted=6.7
# >expected=8.6, predicted=7.5
# >expected=7.6, predicted=7.2
# >expected=8.0, predicted=8.6
# >expected=9.1, predicted=7.5
# >expected=7.3, predicted=7.3
# >expected=4.0, predicted=8.1
# >expected=2.2, predicted=3.7
# >expected=1.9, predicted=6.2
# >expected=7.6, predicted=5.1
# >expected=5.6, predicted=6.8
# >expected=6.3, predicted=5.8
# >expected=5.6, predicted=5.1
# >expected=4.6, predicted=4.8
# >expected=1.8, predicted=3.8
# >expected=5.2, predicted=3.8
# >expected=4.3, predicted=8.3
# >expected=6.2, predicted=8.1
# >expected=4.8, predicted=6.3
# >expected=8.2, predicted=5.8
# >expected=2.7, predicted=4.0
# /Users/parkj/opt/anaconda3/envs/pydeep/lib/python3.8/site-packages/xgboost/data.py:104: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# >expected=22.1, predicted=27.3
# >expected=19.4, predicted=28.7
# >expected=13.7, predicted=20.0
# >expected=14.9, predicted=20.1
# >expected=19.2, predicted=17.2
# >expected=19.3, predicted=22.4
# >expected=20.8, predicted=21.9
# >expected=20.5, predicted=24.7
# >expected=17.6, predicted=20.0
# >expected=12.7, predicted=12.8
# >expected=18.8, predicted=14.6
# >expected=18.0, predicted=19.9
# >expected=19.7, predicted=18.5
# >expected=20.1, predicted=20.4
# >expected=20.5, predicted=22.5
# >expected=18.5, predicted=16.5
# >expected=11.3, predicted=14.7
# >expected=17.1, predicted=17.3
# >expected=17.9, predicted=18.0
# >expected=28.9, predicted=18.8
# >expected=22.5, predicted=25.9
# >expected=25.8, predicted=22.7
# >expected=20.9, predicted=17.8
# >expected=14.4, predicted=15.7
# >expected=23.1, predicted=13.1
# >expected=20.4, predicted=22.3
# >expected=22.2, predicted=24.3
# >expected=26.3, predicted=19.8
# >expected=23.3, predicted=24.8
# >expected=21.1, predicted=22.7
# >expected=11.7, predicted=16.2
# >expected=25.8, predicted=23.9
# >expected=20.2, predicted=23.0
# >expected=25.0, predicted=25.2
# >expected=26.6, predicted=26.3
# >expected=27.5, predicted=25.9
# >expected=22.2, predicted=24.7
# >expected=15.5, predicted=14.9
# >expected=23.3, predicted=24.3
# >expected=25.9, predicted=22.1
# >expected=25.1, predicted=23.6
# >expected=24.7, predicted=26.3
# >expected=26.6, predicted=27.2
# >expected=17.5, predicted=25.7
# >expected=14.0, predicted=16.1
# >expected=22.7, predicted=23.7
# >expected=20.3, predicted=23.1
# >expected=20.9, predicted=24.0
# >expected=22.4, predicted=22.2
# >expected=20.8, predicted=22.4
# >expected=17.8, predicted=16.8
# >expected=10.7, predicted=14.2
# >expected=15.8, predicted=22.5
# >expected=16.9, predicted=19.6
# >expected=18.4, predicted=17.1
# >expected=19.4, predicted=19.1
# >expected=19.3, predicted=18.0
# >expected=15.1, predicted=16.1
# >expected=9.8, predicted=14.7
# >expected=16.8, predicted=14.8
# >expected=13.6, predicted=16.5
# >expected=14.9, predicted=14.2
# >expected=15.8, predicted=15.8
# >expected=16.0, predicted=17.2
# >expected=11.2, predicted=18.1
# >expected=7.1, predicted=9.9
# >expected=12.2, predicted=16.5
# >expected=11.2, predicted=11.2
# >expected=11.9, predicted=11.8
# >expected=12.7, predicted=15.4
# >expected=14.1, predicted=12.6
# >expected=9.6, predicted=10.4
# >expected=5.6, predicted=7.1
# >expected=9.5, predicted=10.4
# >expected=9.2, predicted=9.5
# >expected=9.7, predicted=10.7
# >expected=10.1, predicted=9.7
# >expected=9.3, predicted=11.7
# >expected=6.6, predicted=9.2
# >expected=4.3, predicted=7.2
# >expected=8.6, predicted=7.6
# >expected=7.6, predicted=8.8
# >expected=8.0, predicted=7.6
# >expected=9.1, predicted=8.4
# >expected=7.3, predicted=6.7
# >expected=4.0, predicted=6.8
# >expected=2.2, predicted=4.5
# >expected=1.9, predicted=8.2
# >expected=7.6, predicted=3.9
# >expected=5.6, predicted=7.5
# >expected=6.3, predicted=8.9
# >expected=5.6, predicted=6.5
# >expected=4.6, predicted=4.1
# >expected=1.8, predicted=2.3
# >expected=5.2, predicted=4.5
# >expected=4.3, predicted=9.4
# >expected=6.2, predicted=9.2
# >expected=4.8, predicted=7.7
# >expected=8.2, predicted=6.8
# >expected=2.7, predicted=4.7

# %% [markdown]
# ## 1.8 Visualize Model Performance<a id='1.8_Visualize_Model_Performance'></a>

# %% [markdown]
# ### 1.8.1 Plot Actual (Y) and Predicted (Yhat) Cases<a id='1.8.1_Plot_Actual_and_Predicted_Cases'></a>

# %%
# set up to draw model results
fig, ax = plt.subplots(7, 1, figsize=(12, 24))
fig.subplots_adjust(wspace=0.5, hspace=0.7)
# plot for each of the 7-day forecast
for i, key in enumerate(rez_XGBoost_dict.keys()):
    rez = rez_XGBoost_dict[key]['y_yhat']
    ax[i].plot(rez['date'], rez['y'], 'o-')
    ax[i].plot(rez['date'], rez['yhat'], 'o-')
    ax[i].set(xlabel='Date', ylabel='Percent Cases', title=key)
    ax[i].legend(['y','yhat'], prop=dict(weight='bold',size=14))

# %% [markdown]
# ### 1.8.2 Bar Plot Mean Absolute Errors<a id='1.8.2_Bar_Plot_MAE'></a>

# %%
# create a bar plot for MAEs
mae_7days = []
days = []
for i, key in enumerate(rez_XGBoost_dict.keys()):
    days.append(str('Day'+key[-1]))
    mae_7days.append(rez_XGBoost_dict[key]['error'])
# dataframe MAE for sns bar plot 
df_mae = pd.DataFrame({'Day':days,'MAE':mae_7days})
sns.set_theme(style='whitegrid')
ax = sns.barplot(x='Day', y='MAE', data=df_mae)

# %% [markdown]
# ### 1.8.3 Horizontal Bar Plot Feature Importances<a id='1.8.3_Horizontal_Bar_Plot_Feature_Importances'></a>

# %%
#modelRF.feature_importances_[:-7]
df_xg_rez = pd.DataFrame({'date':df_feat_targ.index[-n_test:], 'y': [float(i) for i in y], 'yhat': yhat})
df_xg_rez.set_index('date',inplace=True)
# feature names used to fit the model 
feat_name = df_feat_targ.columns[:-n_out]
# sort features based on feature importances
sorted_idx = modelXG.feature_importances_.argsort()
# plot feature importance
plt.barh(feat_name[sorted_idx], modelXG.feature_importances_[sorted_idx])
plt.xlabel("Xgboost Feature Importance")
plt.show()

# %% [markdown]
# ## 1.9 Save the Model<a id='1.9_Save_the_Model'></a>

# %%
# save the model
filePath_pickle = Path('/Users/parkj/Documents/pyDat/pyDatCode/covid19/covid19_case_timeSeries_modelXG_7day.pkl')
pickle_out = open(filePath_pickle, 'wb') # open to write binary
pickle.dump(rez_XGBoost_dict, pickle_out)
pickle_out.close()

# %%
# load the model
filePath_pickle = Path('/Users/parkj/Documents/pyDat/pyDatCode/covid19/covid19_case_timeSeries_modelXG_7day.pkl')
pickle_in = open(filePath_pickle, 'rb') # open to read binary
modelXG_7day = pickle.load(pickle_in)
pickle_in.close()

# %%
# visualize a decision tree of the random forest using 'export_graphviz' and 'graphviz'
tree_data = export_graphviz(modelRF.estimators_[0], 
                           feature_names=list(df_feat_targ.columns[:-2]),
                           filled=True, impurity=True, 
                           rounded=True)
graph = graphviz.Source(tree_data, format='pdf')
# render and save the figure 
graph.render('/Users/parkj/Documents/pyDat/pyDatCode/covid19/modelRF_exampleTree', view=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-06505d690679> in <module>
#       1 # visualize a decision tree of the random forest using 'export_graphviz' and 'graphviz'
#       2 tree_data = export_graphviz(modelRF.estimators_[0],
# ----> 3                            feature_names=list(df_feat_targ.columns[:-2]),
#       4                            filled=True, impurity=True,
#       5                            rounded=True)
#
# NameError: name 'df_feat_targ' is not defined

# %%
# Out:
# RandomForestRegressor(n_estimators=1000)
